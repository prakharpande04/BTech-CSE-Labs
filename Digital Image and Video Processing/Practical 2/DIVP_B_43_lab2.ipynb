# %% [markdown]
# ## Prakhar Pande
# ## AIML - B3 - 43

# %%
# Addition of two images

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

add1 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/add1.jpg")
add1 = cv2.resize(add1,(250,250))
print("\nImage 1 : ")
cv2_imshow(add1)

add2 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/add2.jpg")
add2 = cv2.resize(add2,(250,250))
print("\nImage 2 : ")
cv2_imshow(add2)

sum = cv2.add(add1, add2)
print("\nSum : ")
cv2_imshow(sum)

cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/sum.jpg", sum)
# Out:
# Image 1 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Image 2 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Sum :
# <PIL.Image.Image image mode=RGB size=250x250>
# True

# %% [markdown]
# #

# %%
print("Subtraction of two images")

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

sub1 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/sub1.jpg")
sub1 = cv2.resize(sub1,(250,250))
print("\nImage 1 : ")
cv2_imshow(sub1)

sub2 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/sub2.jpg")
sub2 = cv2.resize(sub2,(250,250))
print("\nImage 2 : ")
cv2_imshow(sub2)

diff = cv2.subtract(sub2, sub1)
print("\nDifference : ")
cv2_imshow(diff)

cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/diff.jpg", diff)
# Out:
# Subtraction of two images
#
# Image 1 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Image 2 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Difference :
# <PIL.Image.Image image mode=RGB size=250x250>
# True

# %% [markdown]
# #

# %%
print("Subtraction of two images part 2")

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

sub1 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/sum.jpg")
sub1 = cv2.resize(sub1,(250,250))
print("\nImage 1 : ")
cv2_imshow(sub1)

sub2 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/add1.jpg")
sub2 = cv2.resize(sub2,(250,250))
print("\nImage 2 : ")
cv2_imshow(sub2)

diff2 = cv2.subtract(sub1, sub2)
print("\nDifference : ")
cv2_imshow(diff2)

cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/diff2.jpg", diff2)
# Out:
# Subtraction of two images part 2
#
# Image 1 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Image 2 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Difference :
# <PIL.Image.Image image mode=RGB size=250x250>
# True

# %% [markdown]
# #

# %%
print("Multiplication of image")

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

mul = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/cameraman.jpg")
mul = cv2.resize(mul1,(250,250))
print("\nImage : ")
cv2_imshow(mul)

mul1 = cv2.multiply(mul, 1)
print("\nMultiplication by factor of 1 : ")
cv2_imshow(mul1)

mul2 = cv2.multiply(mul, 2)
print("\nMultiplication by factor of 2 : ")
cv2_imshow(mul2)

mul3 = cv2.multiply(mul, 3)
print("\nMultiplication by factor of 3 : ")
cv2_imshow(mul3)

mul4 = cv2.multiply(mul, 4)
print("\nMultiplication by factor of 4 : ")
cv2_imshow(mul4)

cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/mul1.jpg", mul1)
cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/mul2.jpg", mul2)
cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/mul3.jpg", mul3)
cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/mul4.jpg", mul4)
# Out:
# Multiplication of image
#
# Image :
# <PIL.Image.Image image mode=RGB size=250x250>
# Multiplication by factor of 1 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Multiplication by factor of 2 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Multiplication by factor of 3 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Multiplication by factor of 4 :
# <PIL.Image.Image image mode=RGB size=250x250>
# True

# %% [markdown]
# #

# %%
print("Division of image")

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

div = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/cameraman.jpg")
div = cv2.resize(div,(250,250))
print("\nImage : ")
cv2_imshow(div)

div1 = cv2.divide(div, 1)
print("\nDivision by factor of 1 : ")
cv2_imshow(div1)

div2 = cv2.divide(div, 2)
print("\nDivision by factor of 2 : ")
cv2_imshow(div2)

div3 = cv2.divide(div, 3)
print("\nDivision by factor of 3 : ")
cv2_imshow(div3)

div4 = cv2.divide(div, 4)
print("\nDivision by factor of 4 : ")
cv2_imshow(div4)

cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/div1.jpg", div1)
cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/div2.jpg", div2)
cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/div3.jpg", div3)
cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/div4.jpg", div4)
# Out:
# Division of image
#
# Image :
# <PIL.Image.Image image mode=RGB size=250x250>
# Division by factor of 1 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Division by factor of 2 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Division by factor of 3 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Division by factor of 4 :
# <PIL.Image.Image image mode=RGB size=250x250>
# True

# %% [markdown]
# #

# %%
print("Division of multiplied 4 image")

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

div = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/mul4.jpg")
div = cv2.resize(div,(250,250))
print("\nImage : ")
cv2_imshow(div)

div11 = cv2.divide(div, 1)
print("\nDivision by factor of 1 : ")
cv2_imshow(div11)

div22 = cv2.divide(div, 2)
print("\nDivision by factor of 2 : ")
cv2_imshow(div22)

div33 = cv2.divide(div, 3)
print("\nDivision by factor of 3 : ")
cv2_imshow(div33)

div44 = cv2.divide(div, 4)
print("\nDivision by factor of 4 : ")
cv2_imshow(div44)

cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/div1.jpg", div11)
cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/div2.jpg", div22)
cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/div3.jpg", div33)
cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/div4.jpg", div44)
# Out:
# Division of multiplied 4 image
#
# Image :
# <PIL.Image.Image image mode=RGB size=250x250>
# Division by factor of 1 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Division by factor of 2 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Division by factor of 3 :
# <PIL.Image.Image image mode=RGB size=250x250>
# Division by factor of 4 :
# <PIL.Image.Image image mode=RGB size=250x250>
# True

# %% [markdown]
# #

# %%
print("Bitwise AND operation on images")

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

logical1 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/Logical1.jpg")
logical1 = cv2.resize(logical1,(200,200))
print("\nImage 1 : ")
cv2_imshow(logical1)

logical2 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/logical2.jpg")
logical2 = cv2.resize(logical2,(200,200))
print("\nImage 2 : ")
cv2_imshow(logical2)

AND_image = cv2.bitwise_and(logical1, logical2)
print("\nAND : ")
cv2_imshow(AND_image)

cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/AND.jpg", AND_image)
# Out:
# Bitwise AND operation on images
#
# Image 1 :
# <PIL.Image.Image image mode=RGB size=200x200>
# Image 2 :
# <PIL.Image.Image image mode=RGB size=200x200>
# AND :
# <PIL.Image.Image image mode=RGB size=200x200>
# True

# %%
print("Bitwise OR operation on images")

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

logical1 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/Logical1.jpg")
logical1 = cv2.resize(logical1,(200,200))
print("\nImage 1 : ")
cv2_imshow(logical1)

logical2 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/logical2.jpg")
logical2 = cv2.resize(logical2,(200,200))
print("\nImage 2 : ")
cv2_imshow(logical2)

OR_image = cv2.bitwise_or(logical1, logical2)
print("\nOR : ")
cv2_imshow(OR_image)

cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/OR.jpg", OR_image)
# Out:
# Bitwise OR operation on images
#
# Image 1 :
# <PIL.Image.Image image mode=RGB size=200x200>
# Image 2 :
# <PIL.Image.Image image mode=RGB size=200x200>
# OR :
# <PIL.Image.Image image mode=RGB size=200x200>
# True

# %%
print("Bitwise XOR operation on images")

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

logical1 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/Logical1.jpg")
logical1 = cv2.resize(logical1,(200,200))
print("\nImage 1 : ")
cv2_imshow(logical1)

logical2 = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/logical2.jpg")
logical2 = cv2.resize(logical2,(200,200))
print("\nImage 2 : ")
cv2_imshow(logical2)

XOR_image = cv2.bitwise_xor(logical1, logical2)
print("\nXOR : ")
cv2_imshow(XOR_image)

cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/XOR.jpg", XOR_image)
# Out:
# Bitwise XOR operation on images
#
# Image 1 :
# <PIL.Image.Image image mode=RGB size=200x200>
# Image 2 :
# <PIL.Image.Image image mode=RGB size=200x200>
# XOR :
# <PIL.Image.Image image mode=RGB size=200x200>
# True

# %%
print("Bitwise NOT operation on images")

import cv2
import numpy as np
from google.colab.patches import cv2_imshow

not_image = cv2.imread("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/NOT-operation.jpg")
not_image = cv2.resize(not_image,(200,200))
print("\nOrigional image : ")
cv2_imshow(not_image)

NOT_image = cv2.bitwise_not(not_image)
print("\nNOT operation : ")
cv2_imshow(NOT_image)

cv2.imwrite("/content/drive/MyDrive/Colab-Notebooks/DIVP_LAB/lab2/NOT.jpg", NOT_image)
# Out:
# Bitwise NOT operation on images
#
# Origional image :
# <PIL.Image.Image image mode=RGB size=200x200>
# NOT operation :
# <PIL.Image.Image image mode=RGB size=200x200>
# True
